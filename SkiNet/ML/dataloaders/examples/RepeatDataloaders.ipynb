# %% [markdown]
# # RepeatDalaloaders examples
#
# This notebook presents examples of code where initialising a Dataloader results in spawning new processes each epoch. It also presents examples that prevent this issue.
#
# See more information in the SkiNet documentation under Dataloaders.
#
# # Dataloader - new worker each epoch
#
# - Initialisation of a dataset is the main process
#
# - From this main process we print: SillyDataset __init__ says hello! PID is [98805]
#
# - Then we initialise a dataloader using num_workers=2. For dataloaders, python uses multiprocessing library under the hood
#
# - Once we start iterating over the epochs, **PyTorch spawns separate subprocesses (with their own PIDs)** to handle loading the data
#
# - Basically at the beginning of each epoch we call
#
# ```for batch in loader:```
#
# and under the hood it creates a new iterator
#
# ```
# iterator = iter(loader)
# batch = next(iterator)
# ```
#
#
# -  What happens now is that **PyTorch creates worker processes once we enter __iter__()**. So basically it re-creates workers every time after we call "for batch in loader" = after entering "__iter__()".
# - Here is the __iter__ method of the Dataloader class.
#
# ```
# # We quote '_BaseDataLoaderIter' since it isn't defined yet and the definition can't be moved up
# # since '_BaseDataLoaderIter' references 'DataLoader'.
# def __iter__(self) -> "_BaseDataLoaderIter":
#     # When using a single worker the returned iterator should be
#     # created everytime to avoid resetting its state
#     # However, in the case of a multiple workers iterator
#     # the iterator is only created once in the lifetime of the
#     # DataLoader object so that workers can be reused
#     if self.persistent_workers and self.num_workers > 0:
#         if self._iterator is None:
#             self._iterator = self._get_iterator()
#         else:
#             self._iterator._reset(self)
#         return self._iterator
#     else:
#         return self._get_iterator()
# ```
#
# where the iterator is obtained like this:
#
# ```
# def _get_iterator(self) -> "_BaseDataLoaderIter":
#     if self.num_workers == 0:
#         return _SingleProcessDataLoaderIter(self)
#     else:
#         self.check_worker_number_rationality()
#         return _MultiProcessingDataLoaderIter(self)
# ```
#
# -  The workers are created in the __init__ method of the  _MultiProcessingDataLoaderIter class, where a new process is created using Process:
# -
# ```
# for i in range(self._num_workers):
#     # No certainty which module multiprocessing_context is
#     index_queue = multiprocessing_context.Queue()  # type: ignore[var-annotated]
#     # Need to `cancel_join_thread` here!
#     index_queue.cancel_join_thread()
#     w = multiprocessing_context.Process(
#         target=_utils.worker._worker_loop,
#         args=(
#             self._dataset_kind,
#             self._dataset,
#             index_queue,
#             self._worker_result_queue,
#             self._workers_done_event,
#             self._auto_collation,
#             self._collate_fn,
#             self._drop_last,
#             self._base_seed,
#             self._worker_init_fn,
#             i,
#             self._num_workers,
#             self._persistent_workers,
#             self._shared_seed,
#         ),
#     )
#     w.daemon = True
#     w.start()
#     self._index_queues.append(index_queue)
#     self._workers.append(w)
# ```
#
#
#
# - **The workers are shut down when the sampler is exhausted** as seen in the _MultiProcessingDataLoaderIter._next_data method. At the end of each epoch Pytorch kills old worker processes and at the beginning of the next, it spawns new processes  and these dudes all help call the Dataset's __getitem__() in parallel.
#
# - Each worker grabs a batch of indices from this queue using multiprocessing magic.
#
# - Each worker has its own Dataset instance (deserialized from the main one via pickle)
#
# - Basically, one sees new PIDs every new epoch

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, time

class SillyDataset(Dataset):
    def __init__(self):
        self.pid = os.getpid()
        print(f"This method is being called in the main process! SillyDataset __init__ says hello! PID is [{self.pid}] ")

    def __len__(self):
        return 20

    def __getitem__(self, idx):
        # This print happens inside worker processes when fetching data
        print(f"Fetching index {idx} in __getitem__ of SillyDataset PID is [{os.getpid()}] ")
        return idx

def run_default_dataloader():
    dataset = SillyDataset()
    print("data set initialisation completed")
    loader = DataLoader(dataset, batch_size=4, num_workers=2, shuffle=True)
    print("data loader initialisation completed")


    for epoch in range(5):
        print(f"\n🌍 Epoch {epoch}")
        
        for batch in loader:
            print(f"🔥 Main process [{os.getpid()}] got batch: {batch}")
            time.sleep(0.1)
            #break

run_default_dataloader()
# Out:
# This method is being called in the main process! SillyDataset __init__ says hello! PID is [33883]
# data set initialisation completed
# data loader initialisation completed
#
# 🌍 Epoch 0
# Fetching index 10 in __getitem__ of SillyDataset PID is [34151] Fetching index 14 in __getitem__ of SillyDataset PID is [34150]
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [34151] Fetching index 6 in __getitem__ of SillyDataset PID is [34150]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [34151] Fetching index 12 in __getitem__ of SillyDataset PID is [34150]
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [34150] Fetching index 16 in __getitem__ of SillyDataset PID is [34151]
#
# Fetching index 11 in __getitem__ of SillyDataset PID is [34150] Fetching index 13 in __getitem__ of SillyDataset PID is [34151]
#
# Fetching index 2 in __getitem__ of SillyDataset PID is [34151] Fetching index 17 in __getitem__ of SillyDataset PID is [34150]
#
# Fetching index 1 in __getitem__ of SillyDataset PID is [34150] Fetching index 8 in __getitem__ of SillyDataset PID is [34151]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [34150] Fetching index 15 in __getitem__ of SillyDataset PID is [34151]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [34150]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34150]
# Fetching index 9 in __getitem__ of SillyDataset PID is [34150]
# Fetching index 18 in __getitem__ of SillyDataset PID is [34150]
# 🔥 Main process [33883] got batch: tensor([14,  6, 12,  0])
# 🔥 Main process [33883] got batch: tensor([10,  3,  7, 16])
# 🔥 Main process [33883] got batch: tensor([11, 17,  1,  5])
# 🔥 Main process [33883] got batch: tensor([13,  2,  8, 15])
# 🔥 Main process [33883] got batch: tensor([ 4, 19,  9, 18])
#
# 🌍 Epoch 1
# Fetching index 9 in __getitem__ of SillyDataset PID is [34254]
# Fetching index 0 in __getitem__ of SillyDataset PID is [34254]
# Fetching index 18 in __getitem__ of SillyDataset PID is [34257] Fetching index 10 in __getitem__ of SillyDataset PID is [34254]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [34257] Fetching index 11 in __getitem__ of SillyDataset PID is [34254]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [34257]
# Fetching index 2 in __getitem__ of SillyDataset PID is [34254] Fetching index 12 in __getitem__ of SillyDataset PID is [34257]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [34254] Fetching index 1 in __getitem__ of SillyDataset PID is [34257]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [34254]
# Fetching index 13 in __getitem__ of SillyDataset PID is [34257]
# Fetching index 16 in __getitem__ of SillyDataset PID is [34254]
# Fetching index 5 in __getitem__ of SillyDataset PID is [34257] Fetching index 7 in __getitem__ of SillyDataset PID is [34254]
# Fetching index 3 in __getitem__ of SillyDataset PID is [34257]
# Fetching index 14 in __getitem__ of SillyDataset PID is [34254]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [34254]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34254] 🔥 Main process [33883] got batch: tensor([ 9,  0, 10, 11])
# 🔥 Main process [33883] got batch: tensor([18,  4,  8, 12])
#
# 🔥 Main process [33883] got batch: tensor([ 2, 17,  6, 16])
# 🔥 Main process [33883] got batch: tensor([ 1, 13,  5,  3])
# 🔥 Main process [33883] got batch: tensor([ 7, 14, 15, 19])
#
# 🌍 Epoch 2
# Fetching index 5 in __getitem__ of SillyDataset PID is [34350] Fetching index 12 in __getitem__ of SillyDataset PID is [34351]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [34351] Fetching index 18 in __getitem__ of SillyDataset PID is [34350]
# Fetching index 7 in __getitem__ of SillyDataset PID is [34351]
# Fetching index 4 in __getitem__ of SillyDataset PID is [34351]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [34351] Fetching index 17 in __getitem__ of SillyDataset PID is [34350]
#
# Fetching index 1 in __getitem__ of SillyDataset PID is [34351] Fetching index 11 in __getitem__ of SillyDataset PID is [34350]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [34351] Fetching index 0 in __getitem__ of SillyDataset PID is [34350]
# Fetching index 2 in __getitem__ of SillyDataset PID is [34350]
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [34351] Fetching index 13 in __getitem__ of SillyDataset PID is [34350]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [34350]
# Fetching index 6 in __getitem__ of SillyDataset PID is [34350]
# Fetching index 14 in __getitem__ of SillyDataset PID is [34350]
# Fetching index 16 in __getitem__ of SillyDataset PID is [34350]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34350]
# 🔥 Main process [33883] got batch: tensor([ 5, 18, 17, 11])
# 🔥 Main process [33883] got batch: tensor([12, 10,  7,  4])
# 🔥 Main process [33883] got batch: tensor([ 0,  2, 13,  9])
# 🔥 Main process [33883] got batch: tensor([15,  1,  8,  3])
# 🔥 Main process [33883] got batch: tensor([ 6, 14, 16, 19])
#
# 🌍 Epoch 3
# Fetching index 15 in __getitem__ of SillyDataset PID is [34442]
# Fetching index 2 in __getitem__ of SillyDataset PID is [34442]
# Fetching index 8 in __getitem__ of SillyDataset PID is [34442]
# Fetching index 12 in __getitem__ of SillyDataset PID is [34442]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34442] Fetching index 7 in __getitem__ of SillyDataset PID is [34445]
# Fetching index 3 in __getitem__ of SillyDataset PID is [34442]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [34445]
# Fetching index 16 in __getitem__ of SillyDataset PID is [34445] Fetching index 18 in __getitem__ of SillyDataset PID is [34442]
#
# Fetching index 1 in __getitem__ of SillyDataset PID is [34445]
# Fetching index 11 in __getitem__ of SillyDataset PID is [34445]
# Fetching index 0 in __getitem__ of SillyDataset PID is [34445]
# Fetching index 14 in __getitem__ of SillyDataset PID is [34445]
# Fetching index 6 in __getitem__ of SillyDataset PID is [34445] Fetching index 10 in __getitem__ of SillyDataset PID is [34442]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [34442]
# Fetching index 4 in __getitem__ of SillyDataset PID is [34442]
# Fetching index 5 in __getitem__ of SillyDataset PID is [34442]
# Fetching index 13 in __getitem__ of SillyDataset PID is [34442]
# 🔥 Main process [33883] got batch: tensor([15,  2,  8, 12])
# 🔥 Main process [33883] got batch: tensor([ 7, 17, 16,  1])
# 🔥 Main process [33883] got batch: tensor([19,  3, 18, 10])
# 🔥 Main process [33883] got batch: tensor([11,  0, 14,  6])
# 🔥 Main process [33883] got batch: tensor([ 9,  4,  5, 13])
#
# 🌍 Epoch 4
# Fetching index 14 in __getitem__ of SillyDataset PID is [34537]
# Fetching index 6 in __getitem__ of SillyDataset PID is [34538]
# Fetching index 5 in __getitem__ of SillyDataset PID is [34537] Fetching index 0 in __getitem__ of SillyDataset PID is [34538]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [34537]
# Fetching index 17 in __getitem__ of SillyDataset PID is [34537] Fetching index 12 in __getitem__ of SillyDataset PID is [34538]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [34538]
# Fetching index 16 in __getitem__ of SillyDataset PID is [34537]
# Fetching index 15 in __getitem__ of SillyDataset PID is [34537] Fetching index 1 in __getitem__ of SillyDataset PID is [34538]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [34537] Fetching index 11 in __getitem__ of SillyDataset PID is [34538]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [34538] Fetching index 19 in __getitem__ of SillyDataset PID is [34537]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [34538] Fetching index 2 in __getitem__ of SillyDataset PID is [34537]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [34537]
# Fetching index 3 in __getitem__ of SillyDataset PID is [34537]
# Fetching index 10 in __getitem__ of SillyDataset PID is [34537] 🔥 Main process [33883] got batch: tensor([14,  5,  7, 17])
# 🔥 Main process [33883] got batch: tensor([ 6,  0, 12, 18])
#
# 🔥 Main process [33883] got batch: tensor([16, 15, 13, 19])
# 🔥 Main process [33883] got batch: tensor([ 1, 11,  9,  4])
# 🔥 Main process [33883] got batch: tensor([ 2,  8,  3, 10])

# %% [markdown]
# # Dataloader with persistent workers
#
# - the same PIDs every new epoch

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, time

class SillyDataset(Dataset):
    def __init__(self):
        self.pid = os.getpid()
        print(f"SillyDataset __init__ says hello! PID is [{self.pid}] ")

    def __len__(self):
        return 20

    def __getitem__(self, idx):
        # This print happens inside worker processes when fetching data
        print(f"Fetching index {idx} in __getitem__ of SillyDataset PID is [{os.getpid()}] ")
        return idx

def run_dataloader_persistent_workers():
    dataset = SillyDataset()
    
    loader = DataLoader(
        dataset,
        batch_size=4,
        num_workers=2,
        persistent_workers=True,
        shuffle=True
    )

    for l in loader:
        print("all batches from loader:", l)

    for epoch in range(7):
        print(f"\n🌍 Epoch {epoch}")
        for batch in loader:
            print(f"🔥 Main process [{os.getpid()}] got batch: {batch}")
            time.sleep(0.1)
            #break

run_dataloader_persistent_workers()
# Out:
# SillyDataset __init__ says hello! PID is [33883]
# Fetching index 17 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 11 in __getitem__ of SillyDataset PID is [34853] Fetching index 10 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 7 in __getitem__ of SillyDataset PID is [34854] Fetching index 15 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 12 in __getitem__ of SillyDataset PID is [34853] Fetching index 8 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [34853] Fetching index 18 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 2 in __getitem__ of SillyDataset PID is [34854] Fetching index 5 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 16 in __getitem__ of SillyDataset PID is [34853] Fetching index 0 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 1 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 14 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 3 in __getitem__ of SillyDataset PID is [34853] Fetching index 16 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [34854] all batches from loader: tensor([17, 11, 13, 15])
# all batches from loader: tensor([19, 10,  7,  4])
# all batches from loader: tensor([12,  6,  3,  5])
# all batches from loader: tensor([ 8, 18,  2,  0])
# all batches from loader: tensor([16,  9,  1, 14])
#
# 🌍 Epoch 0
# Fetching index 15 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 14 in __getitem__ of SillyDataset PID is [34854] Fetching index 5 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 0 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 18 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 17 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 4 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 9 in __getitem__ of SillyDataset PID is [34853] Fetching index 11 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [34853] Fetching index 1 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 2 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 13 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 7 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34853]
# 🔥 Main process [33883] got batch: tensor([ 3, 15,  5,  0])
# 🔥 Main process [33883] got batch: tensor([16, 12, 14,  6])
# 🔥 Main process [33883] got batch: tensor([17,  9, 10,  8])
# 🔥 Main process [33883] got batch: tensor([18,  4, 11,  1])
# Fetching index 5 in __getitem__ of SillyDataset PID is [34854] Fetching index 4 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [34853] Fetching index 1 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 17 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [34854] Fetching index 11 in __getitem__ of SillyDataset PID is [34853]
# 🔥 Main process [33883] got batch: tensor([ 2, 13,  7, 19])
#
# 🌍 Epoch 1
# Fetching index 10 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 7 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 2 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 8 in __getitem__ of SillyDataset PID is [34854] Fetching index 19 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 6 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 3 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 16 in __getitem__ of SillyDataset PID is [34853] Fetching index 14 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 12 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 15 in __getitem__ of SillyDataset PID is [34853]
# 🔥 Main process [33883] got batch: tensor([ 4,  0, 17, 11])
# 🔥 Main process [33883] got batch: tensor([ 5,  1, 18, 10])
# 🔥 Main process [33883] got batch: tensor([ 9,  2, 19,  3])
# 🔥 Main process [33883] got batch: tensor([ 7,  8,  6, 14])
# Fetching index 1 in __getitem__ of SillyDataset PID is [34853] Fetching index 9 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [34853] Fetching index 18 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [34853] Fetching index 13 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [34853] Fetching index 3 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 5 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 16 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 17 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 8 in __getitem__ of SillyDataset PID is [34853] Fetching index 15 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 14 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 2 in __getitem__ of SillyDataset PID is [34854] Fetching index 12 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 11 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 0 in __getitem__ of SillyDataset PID is [34853]
# 🔥 Main process [33883] got batch: tensor([16, 13, 12, 15])
#
# 🌍 Epoch 2
# 🔥 Main process [33883] got batch: tensor([ 1,  6,  4, 10])
# 🔥 Main process [33883] got batch: tensor([ 9, 18, 13,  3])
# 🔥 Main process [33883] got batch: tensor([ 5, 19,  8, 14])
# 🔥 Main process [33883] got batch: tensor([16, 17, 15,  2])
# 🔥 Main process [33883] got batch: tensor([12, 11,  7,  0])
# Fetching index 10 in __getitem__ of SillyDataset PID is [34854] Fetching index 13 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 8 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [34854] Fetching index 7 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 6 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [34853] Fetching index 1 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 16 in __getitem__ of SillyDataset PID is [34853] Fetching index 9 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 2 in __getitem__ of SillyDataset PID is [34853] Fetching index 4 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 11 in __getitem__ of SillyDataset PID is [34853] Fetching index 12 in __getitem__ of SillyDataset PID is [34854]
#
#
# 🌍 Epoch 3
# 🔥 Main process [33883] got batch: tensor([13,  8,  7, 15])
# Fetching index 14 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 18 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 0 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 17 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 3 in __getitem__ of SillyDataset PID is [34853]
# 🔥 Main process [33883] got batch: tensor([10, 19,  5,  6])
# 🔥 Main process [33883] got batch: tensor([16,  2, 11, 14])
# 🔥 Main process [33883] got batch: tensor([ 1,  9,  4, 12])
# 🔥 Main process [33883] got batch: tensor([18,  0, 17,  3])
# Fetching index 15 in __getitem__ of SillyDataset PID is [34853] Fetching index 10 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 1 in __getitem__ of SillyDataset PID is [34854] Fetching index 12 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [34854] Fetching index 6 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [34853] Fetching index 14 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [34854] Fetching index 2 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [34854] Fetching index 13 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 16 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 0 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 9 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [34853]
# 🌍 Epoch 4
# 🔥 Main process [33883] got batch: tensor([15, 12,  6, 18])
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 17 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 11 in __getitem__ of SillyDataset PID is [34853]
# 🔥 Main process [33883] got batch: tensor([10,  1,  8, 14])
# 🔥 Main process [33883] got batch: tensor([ 2, 13, 16,  7])
# 🔥 Main process [33883] got batch: tensor([4, 5, 0, 9])
# 🔥 Main process [33883] got batch: tensor([ 3, 19, 17, 11])
# Fetching index 3 in __getitem__ of SillyDataset PID is [34853] Fetching index 6 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [34854] Fetching index 13 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [34854] Fetching index 0 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 14 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 12 in __getitem__ of SillyDataset PID is [34853] Fetching index 4 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 11 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 2 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 16 in __getitem__ of SillyDataset PID is [34853] Fetching index 19 in __getitem__ of SillyDataset PID is [34854]
# Fetching index 15 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 1 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 9 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 10 in __getitem__ of SillyDataset PID is [34853]
# 🌍 Epoch 5
# 🔥 Main process [33883] got batch: tensor([ 3, 13,  0, 14])
#
# 🔥 Main process [33883] got batch: tensor([ 6,  5,  8, 17])
# 🔥 Main process [33883] got batch: tensor([12, 11,  2, 16])
# 🔥 Main process [33883] got batch: tensor([ 4, 18, 19,  1])
# 🔥 Main process [33883] got batch: tensor([15,  7,  9, 10])
# Fetching index 7 in __getitem__ of SillyDataset PID is [34853] Fetching index 10 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [34854] Fetching index 11 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [34854] Fetching index 2 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [34854] Fetching index 16 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 14 in __getitem__ of SillyDataset PID is [34853] Fetching index 3 in __getitem__ of SillyDataset PID is [34854]
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [34854] Fetching index 15 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [34854] Fetching index 13 in __getitem__ of SillyDataset PID is [34853]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [34853] Fetching index 5 in __getitem__ of SillyDataset PID is [34854]
# 🌍 Epoch 6
# 🔥 Main process [33883] got batch: tensor([ 7, 11,  2, 16])
#
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 1 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 19 in __getitem__ of SillyDataset PID is [34853]
# Fetching index 18 in __getitem__ of SillyDataset PID is [34853]
# 🔥 Main process [33883] got batch: tensor([10, 12, 17,  8])
# 🔥 Main process [33883] got batch: tensor([14, 15, 13,  4])
# 🔥 Main process [33883] got batch: tensor([3, 0, 6, 5])
# 🔥 Main process [33883] got batch: tensor([ 9,  1, 19, 18])

# %%
#remove_cell
import sys

#sourcepath = '/Users/Pavel/Documents/repos/SkiNet/'
sourcepath = '/workplace/SkiNet/'

sys.path.insert(0,sourcepath)
#sys.path.insert(0,datapath)

#automatically track changes in the source code
# %load_ext autoreload
# %autoreload 2


# %matplotlib inline

# %%
from SkiNet.ML.dataloaders.dataloaders import RepeatDataLoader

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, time

# set up logging
from SkiNet.Utils.loggers import stdout_logging, file_logging
import logging

stdout_logging(logging.DEBUG)
file_logging()

class SillyDataset(Dataset):
    def __init__(self):
        self.pid = os.getpid()
        print(f"SillyDataset __init__ says hello! PID is [{self.pid}] ")

    def __len__(self):
        return 20

    def __getitem__(self, idx):
        # This print happens inside worker processes when fetching data
        print(f"Fetching index {idx} in __getitem__ of SillyDataset PID is [{os.getpid()}] ")
        return idx

def run_RepeatDataLoader():
    dataset = SillyDataset()
    
    loader = RepeatDataLoader(
        dataset,
        batch_size=4,
        num_workers=2,
        persistent_workers=False,
        max_num_to_repeat=10,
        shuffle=True,
        drop_last=False
    )

    for l in loader:
        print("all batches from loader:", l)

    
    for epoch in range(7):
        print(f"\n🌍 Epoch {epoch}")
        for batch in loader:
            print(f"🔥 Main process [{os.getpid()}] got batch: {batch}")
            time.sleep(0.5)
            #break

run_RepeatDataLoader()
# Out:
# Setting up stdout_logging
# Setting logging level to 10 for stdout logging
# Setting logging level to 10 to log into /workplace/SkiNet/skinet_logs.log
# SillyDataset __init__ says hello! PID is [33883]
# 2025-06-10 16:11:22 - DEBUG [__init__ (85) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeatdl_batch_sampler length 5
# 2025-06-10 16:11:22 - DEBUG [__init__ (86) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeatdl_batch_sampler <torch.utils.data.sampler.BatchSampler object at 0x7fe184d91d50>
# 2025-06-10 16:11:22 - DEBUG [__init__ (90) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeat_sampler length 2
# 2025-06-10 16:11:22 - DEBUG [__init__ (91) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeat_sampler <SkiNet.ML.dataloaders.dataloaders._RepeatSampler object at 0x7fe1854f5990>
# 2025-06-10 16:11:22 - DEBUG [__init__ (99) in SkiNet.ML.dataloaders.dataloaders] - Iterator in RepeatDataloder.__init__ None
# 2025-06-10 16:11:22 - DEBUG [__iter__ (114) in SkiNet.ML.dataloaders.dataloaders] - Iterator in RepeatDataloder.__iter__ is None   None
# 2025-06-10 16:11:22 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# 2025-06-10 16:11:22 - DEBUG [__iter__ (119) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__     <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
# Fetching index 19 in __getitem__ of SillyDataset PID is [37391] Fetching index 4 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 6 in __getitem__ of SillyDataset PID is [37392]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [37391] Fetching index 13 in __getitem__ of SillyDataset PID is [37392]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 1 in __getitem__ of SillyDataset PID is [37391] Fetching index 12 in __getitem__ of SillyDataset PID is [37392]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [37392] Fetching index 16 in __getitem__ of SillyDataset PID is [37391]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [37392] Fetching index 7 in __getitem__ of SillyDataset PID is [37391] all batches from loader: tensor([19,  9, 18,  1])
# 2025-06-10 16:11:23 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
#
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [37391] Fetching index 14 in __getitem__ of SillyDataset PID is [37392]
#
# Fetching index 8 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 0 in __getitem__ of SillyDataset PID is [37391] Fetching index 14 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 4 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 13 in __getitem__ of SillyDataset PID is [37392]
#
# Fetching index 2 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 11 in __getitem__ of SillyDataset PID is [37391] Fetching index 19 in __getitem__ of SillyDataset PID is [37392]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [37392] Fetching index 3 in __getitem__ of SillyDataset PID is [37391]
#
# Fetching index 2 in __getitem__ of SillyDataset PID is [37392] Fetching index 10 in __getitem__ of SillyDataset PID is [37391]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [37392] Fetching index 15 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 17 in __getitem__ of SillyDataset PID is [37392] all batches from loader: tensor([ 4,  6, 13, 12])
# all batches from loader: tensor([16,  7, 15,  0])
# all batches from loader: tensor([ 5, 17, 14,  8])
# all batches from loader: tensor([ 2, 11,  3, 10])
#
# 🌍 Epoch 0
# 2025-06-10 16:11:23 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
#
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 11 in __getitem__ of SillyDataset PID is [37391] Fetching index 1 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 6 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 8 in __getitem__ of SillyDataset PID is [37392]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [37392] Fetching index 12 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([14,  4, 13, 19])
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 16 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 5 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 7 in __getitem__ of SillyDataset PID is [37391]
# 2025-06-10 16:11:23 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# Fetching index 2 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 4 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 11 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 8 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([15, 11,  6, 12])
# Fetching index 6 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 13 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 5 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 1 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([10,  2,  9, 17])
# Fetching index 17 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 16 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 15 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 19 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 3, 16,  5,  7])
# Fetching index 12 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 18 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 7 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 9 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([ 0,  1,  8, 18])
#
# 🌍 Epoch 1
# 2025-06-10 16:11:25 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
# Fetching index 10 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 3 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 0 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 14 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 2,  4, 11,  8])
# 2025-06-10 16:11:26 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# Fetching index 4 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 9 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 2 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 1 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([ 6, 13,  5,  1])
# Fetching index 10 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 7 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 6 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 12 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([17, 16, 15, 19])
# Fetching index 8 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 15 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 5 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 17 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([12, 18,  7,  9])
# Fetching index 18 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 19 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 16 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 14 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([10,  3,  0, 14])
#
# 🌍 Epoch 2
# 2025-06-10 16:11:28 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
# Fetching index 11 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 0 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 13 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 3 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([4, 9, 2, 1])
# 2025-06-10 16:11:28 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# Fetching index 7 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 9 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 12 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 17 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([10,  7,  6, 12])
# Fetching index 6 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 16 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 13 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 14 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([ 8, 15,  5, 17])
# Fetching index 3 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 11 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 0 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 10 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([18, 19, 16, 14])
# Fetching index 18 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 4 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 19 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 8 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([11,  0, 13,  3])
#
# 🌍 Epoch 3
# 2025-06-10 16:11:30 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
# Fetching index 1 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 2 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 15 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 5 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 7,  9, 12, 17])
# 2025-06-10 16:11:31 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# Fetching index 17 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 19 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 7 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 9 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([ 6, 16, 13, 14])
# Fetching index 4 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 2 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 6 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 10 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 3, 11,  0, 10])
# Fetching index 12 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 1 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 14 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 13 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([18,  4, 19,  8])
# Fetching index 16 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 18 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 15 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 11 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 1,  2, 15,  5])
#
# 🌍 Epoch 4
# 2025-06-10 16:11:33 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
# Fetching index 0 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 8 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 5 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 3 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([17, 19,  7,  9])
# 2025-06-10 16:11:33 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# Fetching index 8 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 18 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 1 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 14 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 4,  2,  6, 10])
# Fetching index 0 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 4 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 19 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 9 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([12,  1, 14, 13])
# Fetching index 15 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 17 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 6 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 10 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([16, 18, 15, 11])
# Fetching index 16 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 7 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 5 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 12 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([0, 8, 5, 3])
#
# 🌍 Epoch 5
# 2025-06-10 16:11:35 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
# Fetching index 13 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 11 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 3 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 2 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 8, 18,  1, 14])
# 2025-06-10 16:11:36 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# Fetching index 19 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 9 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 11 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 10 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([ 0,  4, 19,  9])
# Fetching index 18 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 5 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 6 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 15 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([15, 17,  6, 10])
# Fetching index 7 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 2 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 17 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 3 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([16,  7,  5, 12])
# Fetching index 4 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 14 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 13 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 12 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([13, 11,  3,  2])
#
# 🌍 Epoch 6
# 2025-06-10 16:11:38 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fe184beef10>
# Fetching index 1 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 8 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 0 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 16 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([19,  9, 11, 10])
# 2025-06-10 16:11:38 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7fe29c1e5d40>
# Fetching index 1 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 2 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 9 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 6 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([18,  5,  6, 15])
# Fetching index 13 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 10 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 12 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 17 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([ 7,  2, 17,  3])
# Fetching index 5 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 14 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 16 in __getitem__ of SillyDataset PID is [37391]
# Fetching index 19 in __getitem__ of SillyDataset PID is [37391]
# 🔥 Main process [33883] got batch: tensor([ 4, 14, 13, 12])
# Fetching index 18 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 3 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 4 in __getitem__ of SillyDataset PID is [37392]
# Fetching index 0 in __getitem__ of SillyDataset PID is [37392]
# 🔥 Main process [33883] got batch: tensor([ 1,  8,  0, 16])

# %% [markdown]
# # Repeat Dataloader
# - the same PIDs every new epoch
