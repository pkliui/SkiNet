# %% [markdown]
# # RepeatDalaloaders examples
#
# This notebook presents examples of code where initialising a Dataloader results in spawning new processes each epoch. It also presents examples that prevent this issue.
#
# See more information in the SkiNet documentation under Dataloaders.
#
#
# # Regular Dataloader with no persistent workers
# - Dataset and dataloader are being initialised in the main process
# - Note **the PIDs (the workers) are changing with every epoch!**

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, time

class SillyDataset(Dataset):
    def __init__(self):
        self.pid = os.getpid()
        print(f"SillyDataset is being called in the main process! \
        SillyDataset __init__ says hello! PID is [{self.pid}] ")

    def __len__(self):
        return 20

    def __getitem__(self, idx):
        # This print happens inside worker processes when fetching data
        print(f"Fetching index {idx} in __getitem__ of SillyDataset PID is [{os.getpid()}] ")
        return idx

def run_default_dataloader():

    # Main process
    print(f"Main process ID: {os.getpid()}")
        
    dataset = SillyDataset()
    print("data set initialisation completed")
    loader = DataLoader(dataset, batch_size=4, num_workers=2, shuffle=True)
    print("data loader initialisation completed")

    
    for l in loader:
        print("all batches from loader:", l)


    for epoch in range(5):
        print(f"\n🌍 Epoch {epoch}")
        
        for batch in loader:
            print(f"🔥 Main process [{os.getpid()}] got batch: {batch}")
            time.sleep(0.1)
            #break

run_default_dataloader()
# Out:
# Main process ID: 91205
# SillyDataset is being called in the main process!         SillyDataset __init__ says hello! PID is [91205]
# data set initialisation completed
# data loader initialisation completed
# Fetching index 15 in __getitem__ of SillyDataset PID is [89235]
# Fetching index 13 in __getitem__ of SillyDataset PID is [89235]
# Fetching index 6 in __getitem__ of SillyDataset PID is [89235]
# Fetching index 12 in __getitem__ of SillyDataset PID is [89235]
# Fetching index 10 in __getitem__ of SillyDataset PID is [89235]
# Fetching index 18 in __getitem__ of SillyDataset PID is [89235] Fetching index 1 in __getitem__ of SillyDataset PID is [89236]
# Fetching index 8 in __getitem__ of SillyDataset PID is [89235]
# Fetching index 7 in __getitem__ of SillyDataset PID is [89236]
#
# Fetching index 11 in __getitem__ of SillyDataset PID is [89236] Fetching index 3 in __getitem__ of SillyDataset PID is [89235]
# Fetching index 4 in __getitem__ of SillyDataset PID is [89235]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [89236] Fetching index 9 in __getitem__ of SillyDataset PID is [89235]
#
# Fetching index 16 in __getitem__ of SillyDataset PID is [89236] Fetching index 14 in __getitem__ of SillyDataset PID is [89235]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [89235]
# all batches from loader: tensor([15, 13,  6, 12])
# Fetching index 17 in __getitem__ of SillyDataset PID is [89236]
# Fetching index 0 in __getitem__ of SillyDataset PID is [89236]
# Fetching index 2 in __getitem__ of SillyDataset PID is [89236]
# all batches from loader: tensor([ 1,  7, 11, 19])
# all batches from loader: tensor([10, 18,  8,  3])
# all batches from loader: tensor([16, 17,  0,  2])
# all batches from loader: tensor([ 4,  9, 14,  5])
#
# 🌍 Epoch 0
# Fetching index 16 in __getitem__ of SillyDataset PID is [89324]
# Fetching index 0 in __getitem__ of SillyDataset PID is [89324]
# Fetching index 8 in __getitem__ of SillyDataset PID is [89325] Fetching index 15 in __getitem__ of SillyDataset PID is [89324]
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [89324] Fetching index 4 in __getitem__ of SillyDataset PID is [89325]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [89325]
# Fetching index 17 in __getitem__ of SillyDataset PID is [89325] Fetching index 14 in __getitem__ of SillyDataset PID is [89324]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [89325] Fetching index 12 in __getitem__ of SillyDataset PID is [89324]
# Fetching index 5 in __getitem__ of SillyDataset PID is [89325]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [89324] Fetching index 6 in __getitem__ of SillyDataset PID is [89325]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [89324] Fetching index 11 in __getitem__ of SillyDataset PID is [89325]
#
# Fetching index 1 in __getitem__ of SillyDataset PID is [89324]
# Fetching index 2 in __getitem__ of SillyDataset PID is [89324]
# Fetching index 10 in __getitem__ of SillyDataset PID is [89324]
# Fetching index 18 in __getitem__ of SillyDataset PID is [89324] 🔥 Main process [91205] got batch: tensor([16,  0, 15,  3])
#
# 🔥 Main process [91205] got batch: tensor([ 8,  4, 19, 17])
# 🔥 Main process [91205] got batch: tensor([14, 12,  7,  9])
# 🔥 Main process [91205] got batch: tensor([13,  5,  6, 11])
# 🔥 Main process [91205] got batch: tensor([ 1,  2, 10, 18])
#
# 🌍 Epoch 1
# Fetching index 1 in __getitem__ of SillyDataset PID is [89419]
# Fetching index 13 in __getitem__ of SillyDataset PID is [89419]
# Fetching index 7 in __getitem__ of SillyDataset PID is [89420] Fetching index 5 in __getitem__ of SillyDataset PID is [89419]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [89420] Fetching index 8 in __getitem__ of SillyDataset PID is [89419]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [89420]
# Fetching index 0 in __getitem__ of SillyDataset PID is [89420] Fetching index 14 in __getitem__ of SillyDataset PID is [89419]
# Fetching index 3 in __getitem__ of SillyDataset PID is [89420]
# Fetching index 15 in __getitem__ of SillyDataset PID is [89419]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [89419] Fetching index 2 in __getitem__ of SillyDataset PID is [89420]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [89420] Fetching index 10 in __getitem__ of SillyDataset PID is [89419]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [89420]
# Fetching index 11 in __getitem__ of SillyDataset PID is [89419]
# Fetching index 6 in __getitem__ of SillyDataset PID is [89419]
# Fetching index 9 in __getitem__ of SillyDataset PID is [89419]
# Fetching index 16 in __getitem__ of SillyDataset PID is [89419]
# 🔥 Main process [91205] got batch: tensor([ 1, 13,  5,  8])
# 🔥 Main process [91205] got batch: tensor([ 7,  4, 19,  0])
# 🔥 Main process [91205] got batch: tensor([14, 15, 17, 10])
# 🔥 Main process [91205] got batch: tensor([ 3,  2, 12, 18])
# 🔥 Main process [91205] got batch: tensor([11,  6,  9, 16])
#
# 🌍 Epoch 2
# Fetching index 1 in __getitem__ of SillyDataset PID is [89510]
# Fetching index 19 in __getitem__ of SillyDataset PID is [89510]
# Fetching index 7 in __getitem__ of SillyDataset PID is [89510]
# Fetching index 2 in __getitem__ of SillyDataset PID is [89511] Fetching index 9 in __getitem__ of SillyDataset PID is [89510]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [89511]
# Fetching index 11 in __getitem__ of SillyDataset PID is [89510] Fetching index 8 in __getitem__ of SillyDataset PID is [89511]
# Fetching index 10 in __getitem__ of SillyDataset PID is [89511]
#
# Fetching index 16 in __getitem__ of SillyDataset PID is [89511] Fetching index 3 in __getitem__ of SillyDataset PID is [89510]
#
# Fetching index 14 in __getitem__ of SillyDataset PID is [89511]
# Fetching index 13 in __getitem__ of SillyDataset PID is [89510] Fetching index 15 in __getitem__ of SillyDataset PID is [89511]
# Fetching index 0 in __getitem__ of SillyDataset PID is [89510]
# Fetching index 18 in __getitem__ of SillyDataset PID is [89511]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [89510]
# Fetching index 12 in __getitem__ of SillyDataset PID is [89510]
# Fetching index 6 in __getitem__ of SillyDataset PID is [89510]
# 🔥 Main process [91205] got batch: tensor([ 1, 19,  7,  9])
# Fetching index 5 in __getitem__ of SillyDataset PID is [89510]
# 🔥 Main process [91205] got batch: tensor([ 2, 17,  8, 10])
# 🔥 Main process [91205] got batch: tensor([11,  3, 13,  0])
# 🔥 Main process [91205] got batch: tensor([16, 14, 15, 18])
# 🔥 Main process [91205] got batch: tensor([ 4, 12,  6,  5])
#
# 🌍 Epoch 3
# Fetching index 7 in __getitem__ of SillyDataset PID is [89610]
# Fetching index 17 in __getitem__ of SillyDataset PID is [89610]
# Fetching index 10 in __getitem__ of SillyDataset PID is [89610]
# Fetching index 8 in __getitem__ of SillyDataset PID is [89610] Fetching index 2 in __getitem__ of SillyDataset PID is [89611]
#
# Fetching index 11 in __getitem__ of SillyDataset PID is [89611] Fetching index 1 in __getitem__ of SillyDataset PID is [89610]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [89611] Fetching index 0 in __getitem__ of SillyDataset PID is [89610]
#
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [89611] Fetching index 5 in __getitem__ of SillyDataset PID is [89610]
# Fetching index 18 in __getitem__ of SillyDataset PID is [89610] Fetching index 3 in __getitem__ of SillyDataset PID is [89611]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [89611] Fetching index 12 in __getitem__ of SillyDataset PID is [89610]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [89611] Fetching index 19 in __getitem__ of SillyDataset PID is [89610]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [89610] Fetching index 14 in __getitem__ of SillyDataset PID is [89611]
# Fetching index 16 in __getitem__ of SillyDataset PID is [89610]
#
# 🔥 Main process [91205] got batch: tensor([ 7, 17, 10,  8])
# 🔥 Main process [91205] got batch: tensor([ 2, 11,  6,  4])
# 🔥 Main process [91205] got batch: tensor([ 1,  0,  5, 18])
# 🔥 Main process [91205] got batch: tensor([ 3, 15,  9, 14])
# 🔥 Main process [91205] got batch: tensor([12, 19, 13, 16])
#
# 🌍 Epoch 4
# Fetching index 18 in __getitem__ of SillyDataset PID is [89705]
# Fetching index 7 in __getitem__ of SillyDataset PID is [89705]
# Fetching index 5 in __getitem__ of SillyDataset PID is [89706] Fetching index 16 in __getitem__ of SillyDataset PID is [89705]
# Fetching index 9 in __getitem__ of SillyDataset PID is [89706]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [89705] Fetching index 1 in __getitem__ of SillyDataset PID is [89706]
#
# Fetching index 2 in __getitem__ of SillyDataset PID is [89706]
# Fetching index 17 in __getitem__ of SillyDataset PID is [89705] Fetching index 0 in __getitem__ of SillyDataset PID is [89706]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [89706] Fetching index 8 in __getitem__ of SillyDataset PID is [89705]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [89705] Fetching index 3 in __getitem__ of SillyDataset PID is [89706]
#
# Fetching index 14 in __getitem__ of SillyDataset PID is [89706] Fetching index 4 in __getitem__ of SillyDataset PID is [89705]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [89705]
# Fetching index 6 in __getitem__ of SillyDataset PID is [89705]
# Fetching index 11 in __getitem__ of SillyDataset PID is [89705]
# Fetching index 15 in __getitem__ of SillyDataset PID is [89705]
# 🔥 Main process [91205] got batch: tensor([18,  7, 16, 19])
# 🔥 Main process [91205] got batch: tensor([5, 9, 1, 2])
# 🔥 Main process [91205] got batch: tensor([17,  8, 13,  4])
# 🔥 Main process [91205] got batch: tensor([ 0, 12,  3, 14])
# 🔥 Main process [91205] got batch: tensor([10,  6, 11, 15])

# %% [markdown]
# # Dataloader with persistent workers
#
# - NOTE **the same workers every new epoch**

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, time

class SillyDataset(Dataset):
    def __init__(self):
        self.pid = os.getpid()
        print(f"SillyDataset __init__ says hello! PID is [{self.pid}] ")

    def __len__(self):
        return 20

    def __getitem__(self, idx):
        # This print happens inside worker processes when fetching data
        print(f"Fetching index {idx} in __getitem__ of SillyDataset PID is [{os.getpid()}] ")
        return idx

def run_dataloader_persistent_workers():
    dataset = SillyDataset()
    
    loader = DataLoader(
        dataset,
        batch_size=4,
        num_workers=2,
        persistent_workers=True,
        shuffle=True
    )

    for l in loader:
        print("all batches from loader:", l)

    for epoch in range(7):
        print(f"\n🌍 Epoch {epoch}")
        for batch in loader:
            print(f"🔥 Main process [{os.getpid()}] got batch: {batch}")
            time.sleep(0.1)
            #break

run_dataloader_persistent_workers()
# Out:
# SillyDataset __init__ says hello! PID is [91205]
# Fetching index 7 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 16 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 3 in __getitem__ of SillyDataset PID is [90188] Fetching index 1 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 8 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [90189] Fetching index 6 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [90189] Fetching index 13 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [90189] Fetching index 18 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [90189] Fetching index 11 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 2 in __getitem__ of SillyDataset PID is [90189] Fetching index 14 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [90188] Fetching index 15 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [90189] Fetching index 4 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 8 in __getitem__ of SillyDataset PID is [90189] Fetching index 0 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [90188] Fetching index 17 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [90188] Fetching index 1 in __getitem__ of SillyDataset PID is [90189] all batches from loader: tensor([ 7, 16,  3,  8])
# all batches from loader: tensor([ 1, 12, 19, 17])
# all batches from loader: tensor([ 6, 13, 18, 11])
# all batches from loader: tensor([ 9,  2, 15,  5])
# all batches from loader: tensor([14,  0,  4, 10])
#
# 🌍 Epoch 0
#
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 3 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 11 in __getitem__ of SillyDataset PID is [90189] Fetching index 15 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [90189] Fetching index 19 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 14 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 12 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 16 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 18 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 13 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 2 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 5 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 6 in __getitem__ of SillyDataset PID is [90188]
# 🔥 Main process [91205] got batch: tensor([0, 7, 9, 3])
# 🔥 Main process [91205] got batch: tensor([ 8, 17,  1,  4])
# 🔥 Main process [91205] got batch: tensor([15, 19, 14, 18])
# 🔥 Main process [91205] got batch: tensor([11, 10, 12, 16])
# Fetching index 12 in __getitem__ of SillyDataset PID is [90188] Fetching index 19 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [90189] Fetching index 13 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [90189] Fetching index 7 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [90189] Fetching index 8 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 2 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [90188] Fetching index 1 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 11 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 0 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [90189] Fetching index 18 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 14 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 16 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 5 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 6 in __getitem__ of SillyDataset PID is [90188]
# 🔥 Main process [91205] got batch: tensor([13,  2,  5,  6])
#
# 🌍 Epoch 1
# 🔥 Main process [91205] got batch: tensor([12, 13,  7,  8])
# 🔥 Main process [91205] got batch: tensor([19,  4,  3, 10])
# 🔥 Main process [91205] got batch: tensor([ 9,  0, 18, 17])
# 🔥 Main process [91205] got batch: tensor([ 2,  1, 11, 15])
# 🔥 Main process [91205] got batch: tensor([14, 16,  5,  6])
# Fetching index 1 in __getitem__ of SillyDataset PID is [90188] Fetching index 0 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 13 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 7 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 2 in __getitem__ of SillyDataset PID is [90188] Fetching index 18 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 8 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 11 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 16 in __getitem__ of SillyDataset PID is [90188] Fetching index 9 in __getitem__ of SillyDataset PID is [90188] Fetching index 12 in __getitem__ of SillyDataset PID is [90189]
#
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [90188] Fetching index 10 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [90188] Fetching index 15 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 14 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 6 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 3 in __getitem__ of SillyDataset PID is [90188]
#
# 🌍 Epoch 2
# 🔥 Main process [91205] got batch: tensor([ 1, 13,  2,  4])
# 🔥 Main process [91205] got batch: tensor([ 0, 19,  7, 18])
# 🔥 Main process [91205] got batch: tensor([11, 16,  9,  5])
# 🔥 Main process [91205] got batch: tensor([ 8, 12, 10, 15])
# Fetching index 10 in __getitem__ of SillyDataset PID is [90189] Fetching index 0 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [90189] Fetching index 16 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [90188] Fetching index 18 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [90189] Fetching index 3 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [90188] Fetching index 6 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [90189] Fetching index 14 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [90189] Fetching index 19 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 1 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 8 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 12 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 9 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 11 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 2 in __getitem__ of SillyDataset PID is [90188]
# 🔥 Main process [91205] got batch: tensor([17, 14,  6,  3])
#
# 🌍 Epoch 3
# 🔥 Main process [91205] got batch: tensor([ 0, 16, 15,  3])
# 🔥 Main process [91205] got batch: tensor([10,  5, 18, 13])
# 🔥 Main process [91205] got batch: tensor([ 7, 14, 19,  8])
# 🔥 Main process [91205] got batch: tensor([ 6, 17,  4,  1])
# 🔥 Main process [91205] got batch: tensor([12,  9, 11,  2])
# Fetching index 8 in __getitem__ of SillyDataset PID is [90189] Fetching index 11 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [90189] Fetching index 2 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 5 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 18 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 4 in __getitem__ of SillyDataset PID is [90188] Fetching index 19 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [90189] Fetching index 16 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [90188] Fetching index 3 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 1 in __getitem__ of SillyDataset PID is [90189] Fetching index 14 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 17 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 9 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 10 in __getitem__ of SillyDataset PID is [90188]
#
# 🌍 Epoch 4
# 🔥 Main process [91205] got batch: tensor([11,  2, 13,  4])
# 🔥 Main process [91205] got batch: tensor([ 8,  0,  5, 18])
# 🔥 Main process [91205] got batch: tensor([16, 15,  7, 14])
# 🔥 Main process [91205] got batch: tensor([19,  6,  3,  1])
# Fetching index 9 in __getitem__ of SillyDataset PID is [90189] Fetching index 15 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 7 in __getitem__ of SillyDataset PID is [90188] Fetching index 8 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 3 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 17 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [90188] Fetching index 4 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [90188] Fetching index 2 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 1 in __getitem__ of SillyDataset PID is [90188] Fetching index 18 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 10 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 13 in __getitem__ of SillyDataset PID is [90189] Fetching index 16 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 14 in __getitem__ of SillyDataset PID is [90188] Fetching index 11 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 12 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 19 in __getitem__ of SillyDataset PID is [90188]
# 🔥 Main process [91205] got batch: tensor([12, 17,  9, 10])
#
# 🌍 Epoch 5
# 🔥 Main process [91205] got batch: tensor([15,  7,  3,  6])
# 🔥 Main process [91205] got batch: tensor([ 9,  8, 17,  4])
# 🔥 Main process [91205] got batch: tensor([ 5,  1, 10, 16])
# 🔥 Main process [91205] got batch: tensor([ 2, 18, 13, 11])
# 🔥 Main process [91205] got batch: tensor([14,  0, 12, 19])
# Fetching index 5 in __getitem__ of SillyDataset PID is [90189] Fetching index 16 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 1 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 10 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 14 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 4 in __getitem__ of SillyDataset PID is [90189]
# Fetching index 6 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 13 in __getitem__ of SillyDataset PID is [90189] Fetching index 8 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [90188] Fetching index 18 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 0 in __getitem__ of SillyDataset PID is [90189] Fetching index 12 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 2 in __getitem__ of SillyDataset PID is [90189]
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [90189] Fetching index 7 in __getitem__ of SillyDataset PID is [90188]
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 11 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 3 in __getitem__ of SillyDataset PID is [90188]
# Fetching index 15 in __getitem__ of SillyDataset PID is [90188]
#
# 🌍 Epoch 6
# 🔥 Main process [91205] got batch: tensor([16,  1, 14,  6])
# 🔥 Main process [91205] got batch: tensor([ 5, 10,  4, 13])
# 🔥 Main process [91205] got batch: tensor([ 8,  9, 12,  7])
# 🔥 Main process [91205] got batch: tensor([18,  0,  2, 19])
# 🔥 Main process [91205] got batch: tensor([17, 11,  3, 15])

# %%
#remove_cell
import sys

#sourcepath = '/Users/Pavel/Documents/repos/SkiNet/'
sourcepath = '/workplace/SkiNet/'

sys.path.insert(0,sourcepath)
#sys.path.insert(0,datapath)

#automatically track changes in the source code
# %load_ext autoreload
# %autoreload 2


# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2025-06-13 14:43:58 - DEBUG [switch_backend (497) in matplotlib.pyplot] - Loaded backend inline version unknown.

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, time
import logging


from SkiNet.Utils.loggers import stdout_logging, file_logging
from SkiNet.ML.dataloaders.dataloaders import RepeatDataLoader

stdout_logging(logging.DEBUG)
file_logging()

class SillyDataset(Dataset):
    def __init__(self):
        self.pid = os.getpid()
        print(f"SillyDataset __init__ says hello! PID is [{self.pid}] ")

    def __len__(self):
        return 20

    def __getitem__(self, idx):
        # This print happens inside worker processes when fetching data
        print(f"Fetching index {idx} in __getitem__ of SillyDataset PID is [{os.getpid()}] ")
        return idx

def run_RepeatDataLoader():
    dataset = SillyDataset()
    
    loader = RepeatDataLoader(
        dataset,
        batch_size=4,
        num_workers=2,
        persistent_workers=False,
        max_num_to_repeat=10,
        shuffle=True,
        drop_last=False
    )

    for l in loader:
        print("all batches from loader:", l)

    
    for epoch in range(7):
        print(f"\n🌍 Epoch {epoch}")
        for batch in loader:
            print(f"🔥 Main process [{os.getpid()}] got batch: {batch}")
            time.sleep(0.5)
            #break

run_RepeatDataLoader()
# Out:
# Setting logging level to 10 for stdout logging
# SillyDataset __init__ says hello! PID is [91205]
# 2025-06-13 14:44:13 - DEBUG [__init__ (12) in SkiNet.ML.dataloaders.dataloaders] - The process ID in RepeatDataloader: 91205
# 2025-06-13 14:44:13 - DEBUG [__init__ (20) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeatdl_batch_sampler length 5
# 2025-06-13 14:44:13 - DEBUG [__init__ (21) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeatdl_batch_sampler <torch.utils.data.sampler.BatchSampler object at 0x7febf219a290>
# 2025-06-13 14:44:13 - DEBUG [__init__ (23) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeat_sampler length 2
# 2025-06-13 14:44:13 - DEBUG [__init__ (24) in SkiNet.ML.dataloaders.dataloaders] - BatchSampler repeat_sampler <SkiNet.ML.dataloaders.dataloaders._RepeatSampler object at 0x7febf2196010>
# 2025-06-13 14:44:13 - DEBUG [__init__ (27) in SkiNet.ML.dataloaders.dataloaders] - Iterator in RepeatDataloder.__init__ None
# 2025-06-13 14:44:13 - DEBUG [__iter__ (116) in SkiNet.ML.dataloaders.dataloaders] - Iterator in RepeatDataloder.__iter__ is None   None
# 2025-06-13 14:44:13 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2225840>
# 2025-06-13 14:44:13 - DEBUG [__iter__ (121) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__     <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
# Fetching index 2 in __getitem__ of SillyDataset PID is [94353] Fetching index 19 in __getitem__ of SillyDataset PID is [94352]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [94353] Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
#
# Fetching index 16 in __getitem__ of SillyDataset PID is [94353] Fetching index 4 in __getitem__ of SillyDataset PID is [94352]
#
# Fetching index 10 in __getitem__ of SillyDataset PID is [94352] Fetching index 7 in __getitem__ of SillyDataset PID is [94353]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [94353] Fetching index 17 in __getitem__ of SillyDataset PID is [94352]
#
# Fetching index 5 in __getitem__ of SillyDataset PID is [94353] Fetching index 1 in __getitem__ of SillyDataset PID is [94352]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [94353] Fetching index 18 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 8 in __getitem__ of SillyDataset PID is [94353]
#
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [94352] Fetching index 3 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 14 in __getitem__ of SillyDataset PID is [94352]
# all batches from loader: tensor([19, 13,  4, 10])
# 2025-06-13 14:44:13 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2225240>
# Fetching index 0 in __getitem__ of SillyDataset PID is [94352]
# all batches from loader: Fetching index 5 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 8 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 11 in __getitem__ of SillyDataset PID is [94353] Fetching index 16 in __getitem__ of SillyDataset PID is [94352] tensor([ 2,  6, 16,  7])
# all batches from loader: tensor([17,  1, 18,  9])
# all batches from loader: tensor([12,  5, 15,  8])
#
#
# Fetching index 19 in __getitem__ of SillyDataset PID is [94353] Fetching index 14 in __getitem__ of SillyDataset PID is [94352] all batches from loader: tensor([ 3, 11, 14,  0])
#
# 🌍 Epoch 0
# 2025-06-13 14:44:13 - DEBUG [__iter__ (123) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
#
#
# Fetching index 17 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 4 in __getitem__ of SillyDataset PID is [94352] Fetching index 10 in __getitem__ of SillyDataset PID is [94353]
#
# Fetching index 15 in __getitem__ of SillyDataset PID is [94352] Fetching index 2 in __getitem__ of SillyDataset PID is [94353]
#
# Fetching index 12 in __getitem__ of SillyDataset PID is [94353] Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
#
# Fetching index 9 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 0 in __getitem__ of SillyDataset PID is [94352] Fetching index 18 in __getitem__ of SillyDataset PID is [94353]
#
# Fetching index 6 in __getitem__ of SillyDataset PID is [94353] Fetching index 1 in __getitem__ of SillyDataset PID is [94352]
#
# Fetching index 3 in __getitem__ of SillyDataset PID is [94353] Fetching index 7 in __getitem__ of SillyDataset PID is [94352]
#
# 🔥 Main process [91205] got batch: tensor([ 5,  8, 11, 19])
# 2025-06-13 14:44:14 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2224240>
# Fetching index 12 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 1 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 15 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 9 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([16, 14,  4, 15])
# Fetching index 5 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 4 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 16 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 17 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([17, 10,  2, 12])
# Fetching index 10 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 19 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 8 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 2 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([13,  0,  1,  7])
# Fetching index 14 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 7 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 0 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 6 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 9, 18,  6,  3])
#
# 🌍 Epoch 1
# 2025-06-13 14:44:16 - DEBUG [__iter__ (123) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
# Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 3 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 18 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([12,  1, 15,  9])
# 2025-06-13 14:44:16 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2225840>
# Fetching index 6 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 13 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 18 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 15 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 5,  4, 16, 17])
# Fetching index 4 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 2 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 5 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([10, 19,  8,  2])
# Fetching index 17 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 9 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 16 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 8 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([14,  7,  0,  6])
# Fetching index 0 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 14 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 7 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 3 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([13,  3, 18, 11])
#
# 🌍 Epoch 2
# 2025-06-13 14:44:18 - DEBUG [__iter__ (123) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
# Fetching index 1 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 12 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 10 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 19 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 6, 13, 18, 15])
# 2025-06-13 14:44:19 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2224040>
# Fetching index 0 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 15 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 8 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([ 4,  2,  5, 11])
# Fetching index 10 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 18 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 6 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 17 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([17,  9, 16,  8])
# Fetching index 12 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 14 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 5 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 1 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([ 0, 14,  7,  3])
# Fetching index 9 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 19 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 4 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 3 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 1, 12, 10, 19])
#
# 🌍 Epoch 3
# 2025-06-13 14:44:21 - DEBUG [__iter__ (123) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
# Fetching index 7 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 2 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 16 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([ 0, 15,  8, 13])
# 2025-06-13 14:44:22 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2224240>
# Fetching index 7 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 9 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 12 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 15 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([10, 18,  6, 17])
# Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 19 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 5 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 6 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([12, 14,  5,  1])
# Fetching index 8 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 2 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 18 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 3 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 9, 19,  4,  3])
# Fetching index 10 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 14 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 17 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([ 7, 11,  2, 16])
#
# 🌍 Epoch 4
# 2025-06-13 14:44:24 - DEBUG [__iter__ (123) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
# Fetching index 16 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 1 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 0 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 4 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 7,  9, 12, 15])
# 2025-06-13 14:44:24 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2225840>
# Fetching index 0 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 3 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 16 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([13, 19,  5,  6])
# Fetching index 17 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 19 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 9 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 14 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 8,  2, 18,  3])
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 7 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 10 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 5 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([10, 14, 11, 17])
# Fetching index 18 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 4 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 1 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 8 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([16,  1,  0,  4])
#
# 🌍 Epoch 5
# 2025-06-13 14:44:26 - DEBUG [__iter__ (123) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
# Fetching index 2 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 15 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 12 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 6 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([ 0, 13,  3, 16])
# 2025-06-13 14:44:27 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2224040>
# Fetching index 1 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 0 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 3 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 10 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([17, 19,  9, 14])
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 9 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 7 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 19 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([11,  7, 10,  5])
# Fetching index 14 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 4 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 16 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 17 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([18,  4,  1,  8])
# Fetching index 8 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 2 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 18 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([ 2, 15, 12,  6])
#
# 🌍 Epoch 6
# 2025-06-13 14:44:29 - DEBUG [__iter__ (123) in SkiNet.ML.dataloaders.dataloaders] -  Iterator in RepeatDataloder.__iter__  is being reused    <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7febf2472210>
# Fetching index 5 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 6 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 12 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 15 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 1,  0,  3, 10])
# 2025-06-13 14:44:29 - DEBUG [__iter__ (44) in SkiNet.ML.dataloaders.dataloaders] - Iter of sampler in RepeatSampler.__iter__   <generator object BatchSampler.__iter__ at 0x7febf2224040>
# Fetching index 15 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 1 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 18 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 13 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([11,  9,  7, 19])
# Fetching index 6 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 8 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 4 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 9 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([14,  4, 16, 17])
# Fetching index 14 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 11 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 10 in __getitem__ of SillyDataset PID is [94352]
# Fetching index 19 in __getitem__ of SillyDataset PID is [94352]
# 🔥 Main process [91205] got batch: tensor([ 8,  2, 18, 13])
# Fetching index 12 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 5 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 16 in __getitem__ of SillyDataset PID is [94353]
# Fetching index 0 in __getitem__ of SillyDataset PID is [94353]
# 🔥 Main process [91205] got batch: tensor([ 5,  6, 12, 15])

# %% [markdown]
# # Repeat Dataloader
# - the same PIDs every new epoch
